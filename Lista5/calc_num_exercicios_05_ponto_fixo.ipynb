# %% [markdown]
# # Lista de Exercícios 05 – Raízes de Equações – Ponto fixo

# %% [markdown]
# ## 1 - Utilize o método do ponto fixo para encontre a raiz aproximada das seguintes equações. Considere os seguintes pontos:
# - Precisão de 6 casas decimais;
# - Número máximo de 50 iterações e $\epsilon < 10^{-5}$;
# - Isole o intervalo da raiz;
# - Analise a convergência do método;
# - Apresente o código, solução e passo a passo para chegar nas respostas.

# %%
import numpy as np
import sympy as sy
import matplotlib.pyplot as pyplot
from IPython.display import Math

def plot(fx, intervalo):
    xx = np.linspace(intervalo[0], intervalo[1])
    pyplot.plot(xx, fx(xx), label='f(x)')
    pyplot.grid()
    pyplot.show()

def plot3(fx, gx, glx, intervalo):
    xx = np.linspace(intervalo[0], intervalo[1])
    pyplot.plot(xx, fx(xx), label='f(x)')
    pyplot.plot(xx, gx(xx), label='g(x)')
    pyplot.plot(xx, glx(xx), label="g'(x)")
    pyplot.legend()
    pyplot.grid()
    pyplot.show()

def valor_maximo(fx, intervalo):
    xx = np.linspace(intervalo[0], intervalo[1])
    yy = np.abs(fx(xx))
    return np.max(yy)

# %% [markdown]
# ### a) $f(x) = (x + 0.5)^3 \times e^{(2 - x^2)}$

# %%
x = sy.Symbol('x')
fx_ = (x + 0.5)**3 * sy.exp(2 - x**2)
display(Math('f(x) = ' + sy.latex(fx_)))
fx = sy.lambdify(x, fx_)
#plot(fx, [-100, 100])
#plot(fx, [-25, 0])
#plot(fx, [-5, 0])
plot(fx, [-1, 0])

intervalo = [-1, 0]
gx_ = x - 0.5 * fx_
display(Math('g(x) = ' + sy.latex(gx_)))
glx_ = sy.diff(gx_, x)
display(Math('g\'(x) = ' + sy.latex(glx_)))
gx = sy.lambdify(x, gx_)
glx = sy.lambdify(x, glx_)
plot3(fx, gx, glx, intervalo)
max_glx = valor_maximo(glx, intervalo)
display(Math('|max(g\'(x))| = ' + str(max_glx)))
# Out:
# $\displaystyle f(x) = \left(x + 0.5\right)^{3} e^{2 - x^{2}}$
# $\displaystyle g(x) = x - 0.5 \left(x + 0.5\right)^{3} e^{2 - x^{2}}$
# $\displaystyle g'(x) = 1.0 x \left(x + 0.5\right)^{3} e^{2 - x^{2}} - 1.5 \left(x + 0.5\right)^{2} e^{2 - x^{2}} + 1$
# $\displaystyle |max(g'(x))| = 1.7708960370989937$

# %% [markdown]
# ### b) $f(x) = x^3 \times \cos{(x)}$

# %%
x = sy.Symbol('x')
fx_ = x**3 * sy.cos(x)
display(Math('f(x) = ' + sy.latex(fx_)))
fx = sy.lambdify(x, fx_)
plot(fx, [-1, 1])
intervalo = [-1, 1]

gx_ = x - 0.5 * fx_
display(Math('g(x) = ' + sy.latex(gx_)))
glx_ = sy.diff(gx_, x)
display(Math('g\'(x) = ' + sy.latex(glx_)))
gx = sy.lambdify(x, gx_)
glx = sy.lambdify(x, glx_)
plot3(fx, gx, glx, intervalo)
max_glx = valor_maximo(glx, intervalo)
display(Math('|max(g\'(x))| = ' + str(max_glx)))
# Out:
# $\displaystyle f(x) = x^{3} \cos{\left(x \right)}$
# $\displaystyle g(x) = - 0.5 x^{3} \cos{\left(x \right)} + x$
# $\displaystyle g'(x) = 0.5 x^{3} \sin{\left(x \right)} - 1.5 x^{2} \cos{\left(x \right)} + 1$
# $\displaystyle |max(g'(x))| = 0.999375477130826$

# %% [markdown]
# ### c) $f(x) = 2x^5 - 20x^4 + 5x^3 + x - 1$

# %%
x = sy.Symbol('x')
fx_ = 2 * x**5 - 20 * x**4 + 5 * x**3 + x - 1
display(Math('f(x) = ' + sy.latex(fx_)))
fx = sy.lambdify(x, fx_)
# Plot para visualizar a função e determinar o intervalo
#plot(fx, [1, 3])
plot(fx, [9, 10]) # Refinando o intervalo para encontrar a raiz
intervalo = [9, 10] # Intervalo onde a raiz está presente

gx_ = x - 0.5 * fx_ # g(x) = x - 0.5*f(x)
display(Math('g(x) = ' + sy.latex(gx_)))
glx_ = sy.diff(gx_, x)
display(Math('g\'(x) = ' + sy.latex(glx_)))
gx = sy.lambdify(x, gx_)
glx = sy.lambdify(x, glx_)
plot3(fx, gx, glx, intervalo)
max_glx = valor_maximo(glx, intervalo)
display(Math('|max(g\'(x))| = ' + str(max_glx)))
# Out:
# $\displaystyle f(x) = 2 x^{5} - 20 x^{4} + 5 x^{3} + x - 1$
# $\displaystyle g(x) = - 1.0 x^{5} + 10.0 x^{4} - 2.5 x^{3} + 0.5 x + 0.5$
# $\displaystyle g'(x) = - 5.0 x^{4} + 40.0 x^{3} - 7.5 x^{2} + 0.5$
# $\displaystyle |max(g'(x))| = 10749.5$

# %% [markdown]
# ### d) $f(x) = \dfrac{1}{2} \sin(x^2) \cos(x)$

# %%
x = sy.Symbol('x')
fx_ = sy.cos(x) * (sy.sin(x**2))/2
display(Math('f(x) = ' + sy.latex(fx_)))
fx = sy.lambdify(x, fx_)
# Plot para visualizar a função e determinar o intervalo
#plot(fx, [-10, 10])
#plot(fx, [0, 2])
plot(fx, [-45.58, -45.56]) # Refinando o intervalo para encontrar a raiz
intervalo = [-45.58, -45.56] # Intervalo onde a raiz está presente

gx_ = x - 0.5 * fx_ # g(x) = x - 0.5*f(x)
display(Math('g(x) = ' + sy.latex(gx_)))
glx_ = sy.diff(gx_, x)
display(Math('g\'(x) = ' + sy.latex(glx_)))
gx = sy.lambdify(x, gx_)
glx = sy.lambdify(x, glx_)
plot3(fx, gx, glx, intervalo)
max_glx = valor_maximo(glx, intervalo)
display(Math('|max(g\'(x))| = ' + str(max_glx)))
# Out:
# $\displaystyle f(x) = \frac{\sin{\left(x^{2} \right)} \cos{\left(x \right)}}{2}$
# $\displaystyle g(x) = x - 0.25 \sin{\left(x^{2} \right)} \cos{\left(x \right)}$
# $\displaystyle g'(x) = - 0.5 x \cos{\left(x \right)} \cos{\left(x^{2} \right)} + 0.25 \sin{\left(x \right)} \sin{\left(x^{2} \right)} + 1$
# $\displaystyle |max(g'(x))| = 1.5837054133435116$

# %% [markdown]
# ### e) $f(x) = \frac{(2x^3 - 4x + 1) \times \sin(x)}{x^2 + 1}$

# %%
x = sy.Symbol('x')
fx_ = (2*x**3 - 4*x + 1) * sy.sin(x) / (x**2 + 1)
display(Math('f(x) = ' + sy.latex(fx_)))
fx = sy.lambdify(x, fx_)
# Plot para visualizar a função e determinar o intervalo
#plot(fx, [-10, 10])
plot(fx, [1.2, 1.4]) # Refinando o intervalo para encontrar a raiz
intervalo = [1.2, 1.4] # Intervalo onde a raiz está presente

gx_ = x - 0.5 * fx_ # g(x) = x - 0.5*f(x)
display(Math('g(x) = ' + sy.latex(gx_)))
glx_ = sy.diff(gx_, x)
display(Math('g\'(x) = ' + sy.latex(glx_)))
gx = sy.lambdify(x, gx_)
glx = sy.lambdify(x, glx_)
plot3(fx, gx, glx, intervalo)
max_glx = valor_maximo(glx, intervalo)
display(Math('|max(g\'(x))| = ' + str(max_glx)))
# Out:
# $\displaystyle f(x) = \frac{\left(2 x^{3} - 4 x + 1\right) \sin{\left(x \right)}}{x^{2} + 1}$
# $\displaystyle g(x) = x - \frac{0.5 \left(2 x^{3} - 4 x + 1\right) \sin{\left(x \right)}}{x^{2} + 1}$
# $\displaystyle g'(x) = \frac{1.0 x \left(2 x^{3} - 4 x + 1\right) \sin{\left(x \right)}}{\left(x^{2} + 1\right)^{2}} + 1 - \frac{0.5 \left(6 x^{2} - 4\right) \sin{\left(x \right)}}{x^{2} + 1} - \frac{0.5 \left(2 x^{3} - 4 x + 1\right) \cos{\left(x \right)}}{x^{2} + 1}$
# $\displaystyle |max(g'(x))| = 0.17740590446208723$
